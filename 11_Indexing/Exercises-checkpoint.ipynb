# %% [markdown]
# # Ex -

# %% [markdown]
# ### Introduction:
#
# This time you will create a data
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import ydata_profiling as profil

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called

# %%
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep = '\t')
# profil.ProfileReport(df)

# %% [markdown]
# ## FIRST STEP IS TO CLEAN THE DATA AND HANDLING THE MISSISNG VALSUES "NaN"

# %% [markdown]
# ### Show the first 10 rows of data

# %%
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5.

# %%
### Set the order_id as the default index
df.set_index('order_id', inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 2
#       1 ### Set the order_id as the default index
# ----> 2 df.set_index('order_id', inplace=True)
#       3 df
#
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:6012, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
# ...

# %% [markdown]
# ### Step 6.

# %%
df.isnull().sum()
# Out:
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %% [markdown]
# ### Handling The Messing Values

# %%
df['choice_description'].fillna(df['item_name'], inplace=True)

# %%
df
# Out:
#           quantity                              item_name  \
# order_id
# 1                1           Chips and Fresh Tomato Salsa
# 1                1                                   Izze
# 1                1                       Nantucket Nectar
# 1                1  Chips and Tomatillo-Green Chili Salsa
# 2                2                           Chicken Bowl
# ...            ...                                    ...
# 1833             1                          Steak Burrito
# 1833             1                          Steak Burrito
# 1834             1                     Chicken Salad Bowl
# 1834             1                     Chicken Salad Bowl
# 1834             1                     Chicken Salad Bowl
#
#                                          choice_description item_price
# order_id
# 1                              Chips and Fresh Tomato Salsa     $2.39
# 1                                              [Clementine]     $3.39
# ...

# %% [markdown]
# ### Chick the columns data types ara they match or not and if they do not match convert each column to the right data type

# %%
df.dtypes
# Out:
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
df['item_price'] = df['item_price'].str.replace('$', '').astype(float)  # Convert item_price to numeric
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2936\4193055209.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['item_price'] = df['item_price'].str.replace('$', '').astype(float)  # Convert item_price to numeric

# %%
df['item_price'].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# 1. What is the distribution of quantities sold for different items?

# %%
df.groupby('item_name')['quantity'].describe()
# Out:
#                                        count      mean       std  min  25%  \
# item_name
# 6 Pack Soft Drink                       54.0  1.018519  0.136083  1.0  1.0
# Barbacoa Bowl                           66.0  1.000000  0.000000  1.0  1.0
# Barbacoa Burrito                        91.0  1.000000  0.000000  1.0  1.0
# Barbacoa Crispy Tacos                   11.0  1.090909  0.301511  1.0  1.0
# Barbacoa Salad Bowl                     10.0  1.000000  0.000000  1.0  1.0
# Barbacoa Soft Tacos                     25.0  1.000000  0.000000  1.0  1.0
# Bottled Water                          162.0  1.302469  1.034135  1.0  1.0
# Bowl                                     2.0  2.000000  1.414214  1.0  1.5
# Burrito                                  6.0  1.000000  0.000000  1.0  1.0
# Canned Soda                            104.0  1.211538  0.476090  1.0  1.0
# Canned Soft Drink                      301.0  1.166113  0.495629  1.0  1.0
# ...

# %%
plt.figure(figsize=(10, 6))
for item_name, group_df in df.groupby('item_name'):
    plt.hist(group_df['quantity'], bins=10, alpha=0.6, label=item_name)

plt.xlabel('Quantity Sold')
plt.ylabel('Frequency')
plt.title('Distribution of Quantities Sold for Different Items')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# 2. Which are the top 5 most frequently ordered items?

# %%
top_5_orderd_items = df.nlargest(5, 'quantity')

top_5_orderd_items
# Out:
#           quantity                     item_name  \
# order_id
# 1443            15  Chips and Fresh Tomato Salsa
# 1660            10                 Bottled Water
# 1559             8                 Side of Chips
# 1443             7                 Bottled Water
# 970              5                 Bottled Water
#
#                     choice_description  item_price
# order_id
# 1443      Chips and Fresh Tomato Salsa       44.25
# 1660                     Bottled Water       15.00
# 1559                     Side of Chips       13.52
# 1443                     Bottled Water       10.50
# 970                      Bottled Water        7.50

# %% [markdown]
# 3. How does the item price vary with different item names?

# %% [markdown]
# 4. What are the most common choice descriptions for specific items?

# %%
df.groupby(['item_name', 'choice_description'])['quantity'].max()
# Out:
# item_name          choice_description
# 6 Pack Soft Drink  [Coke]                                                                                                               1
#                    [Diet Coke]                                                                                                          2
#                    [Lemonade]                                                                                                           1
#                    [Nestea]                                                                                                             1
#                    [Sprite]                                                                                                             1
#                                                                                                                                        ..
# ...

# %% [markdown]
# 5. What is the total revenue generated from item sales?

# %%
df['revenue'] = df['quantity'] * df['item_price']
df['revenue'].sum()
# Out:
# 39237.02

# %% [markdown]
# 6. Are there any outliers in the item price column?

# %%
# Calculate Z-score for each value
z_scores = np.abs((df['item_price'] - df['item_price'].mean()) / df['item_price'].std())

# Threshold for outliers (e.g., 3 standard deviations from the mean)
threshold = 45

# Identify outliers
outliers = df[z_scores > threshold]

outliers
# Out:
# Empty DataFrame
# Columns: [quantity, item_name, choice_description, item_price, revenue]
# Index: []

# %% [markdown]
# 7. How do the item prices differ across different quantities sold?

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['quantity'], df['item_price'])
plt.xlabel('Quantity Sold')  # Corrected the function name
plt.ylabel('Item Price')
plt.title('Item Prices vs. Quantities Sold')
plt.show()

# %%
# Create a scatter plot to visualize item prices across different quantities sold
plt.figure(figsize=(10, 6))
plt.scatter(df['quantity'], df['item_price'])
plt.xlabel('Qulantity Sold')
plt.ylabel('Item Price')
plt.title('Item Prices vs. Quantities Sold')
plt.bar(df['quantity'],df['item_price'])
plt.show()

# %% [markdown]
# 8. What is the average quantity of items sold per order?

# %%
df.head()
# Out:
#           quantity                              item_name  \
# order_id
# 1                1           Chips and Fresh Tomato Salsa
# 1                1                                   Izze
# 1                1                       Nantucket Nectar
# 1                1  Chips and Tomatillo-Green Chili Salsa
# 2                2                           Chicken Bowl
#
#                                          choice_description  item_price  \
# order_id
# 1                              Chips and Fresh Tomato Salsa        2.39
# 1                                              [Clementine]        3.39
# 1                                                   [Apple]        3.39
# 1                     Chips and Tomatillo-Green Chili Salsa        2.39
# 2         [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
#
#           revenue
# order_id
# 1            2.39
# 1            3.39
# 1            3.39
# 1            2.39
# 2           33.96

# %%
avg_quantity_sold_per_order = df.groupby('item_name')['quantity'].mean()
pd.DataFrame(avg_quantity_sold_per_order)
# Out:
#                                        quantity
# item_name
# 6 Pack Soft Drink                      1.018519
# Barbacoa Bowl                          1.000000
# Barbacoa Burrito                       1.000000
# Barbacoa Crispy Tacos                  1.090909
# Barbacoa Salad Bowl                    1.000000
# Barbacoa Soft Tacos                    1.000000
# Bottled Water                          1.302469
# Bowl                                   2.000000
# Burrito                                1.000000
# Canned Soda                            1.211538
# Canned Soft Drink                      1.166113
# Carnitas Bowl                          1.044118
# Carnitas Burrito                       1.016949
# Carnitas Crispy Tacos                  1.142857
# Carnitas Salad                         1.000000
# Carnitas Salad Bowl                    1.000000
# Carnitas Soft Tacos                    1.000000
# Chicken Bowl                           1.048209
# ...

# %% [markdown]
# 9. How does the distribution of quantities sold differ for different item names?

# %% [markdown]
# 10. What are the most popular items based on total quantity sold?

# %%
df.head(-10)
# Out:
#           quantity                              item_name  \
# order_id
# 1                1           Chips and Fresh Tomato Salsa
# 1                1                                   Izze
# 1                1                       Nantucket Nectar
# 1                1  Chips and Tomatillo-Green Chili Salsa
# 2                2                           Chicken Bowl
# ...            ...                                    ...
# 1829             1                          Steak Burrito
# 1829             1                         Veggie Burrito
# 1829             1                      Canned Soft Drink
# 1830             1                          Steak Burrito
# 1830             1                         Veggie Burrito
#
#                                          choice_description  item_price  \
# order_id
# 1                              Chips and Fresh Tomato Salsa        2.39
# 1                                              [Clementine]        3.39
# ...

# %%
most_popular_item = df.loc[df['quantity'].idxmax(), 'item_name']
most_popular_item
# Out:
# order_id
# 1443    Chips and Fresh Tomato Salsa
# 1443                   Bottled Water
# 1443               6 Pack Soft Drink
# 1443                  Veggie Burrito
# 1443                 Chicken Burrito
# 1443                   Steak Burrito
# 1443                   Bottled Water
# Name: item_name, dtype: object

# %% [markdown]
# 12. Is there any seasonality or trend in the quantity of items sold over time?
# 13. Are there any associations between specific item names and choice descriptions?
# 14. How does the quantity of items sold change with different price ranges?
# 15. Which item names have the highest revenue and profit?

# %% [markdown]
# # 1.What is the total quantity of items sold in the dataset?
# # 2.Which item_name appears the most frequently in the dataset?
# # 3.What are the most popular choice_description(s) among customers?
# # 4.What is the average item_price for all items in the dataset?
# # 5.How does the item_price vary with different choice_description(s)?
# # 6.Are there any items with unusual quantities that require further investigation?
# # 7.Can you identify any specific patterns or trends in item_name and quantity sold?
# # 8.What is the total revenue generated from item sales?

# %%
df['quantity'].sum()
# Out:
# 4972

# %%
df['item_name'].mode().values[0]
# Out:
# 'Chicken Bowl'

# %%
df['choice_description'].mode().values[0]
# Out:
# 'Chips and Guacamole'

# %%
df.groupby('choice_description')['item_price'].mean()
# Out:
# choice_description
# Bottled Water                                                                                                                                  1.867654
# Chips                                                                                                                                          2.342844
# Chips and Fresh Tomato Salsa                                                                                                                   3.285091
# Chips and Guacamole                                                                                                                            4.595073
# Chips and Mild Fresh Tomato Salsa                                                                                                              3.000000
#                                                                                                                                                  ...
# ...

# %%
df[df['quantity'] < 0].sum()
# Out:
# quantity              0.0
# item_name             0.0
# choice_description    0.0
# item_price            0.0
# revenue               0.0
# dtype: float64

# %% [markdown]
# 12. Sort item names  by there quantities ascendingly

# %%
df.groupby('item_name')['quantity'].sum().sort_values(ascending=False)
# Out:
# item_name
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chips and Guacamole                      506
# Steak Burrito                            386
# Canned Soft Drink                        351
# Chips                                    230
# Steak Bowl                               221
# Bottled Water                            211
# Chips and Fresh Tomato Salsa             130
# Canned Soda                              126
# Chicken Salad Bowl                       123
# Chicken Soft Tacos                       120
# Side of Chips                            110
# Veggie Burrito                            97
# Barbacoa Burrito                          91
# Veggie Bowl                               87
# Carnitas Bowl                             71
# Barbacoa Bowl                             66
# Carnitas Burrito                          60
# Steak Soft Tacos                          56
# 6 Pack Soft Drink                         55
# ...

# %%
(df['item_price'] * df['quantity']).sum()
# Out:
# 39237.02

# %%
df['choice_description'].fillna(df['item_name'], inplace=True)

# %%
df.describe()

# %% [markdown]
# ### Step 7.

# %% [markdown]
# ### Step 8.

# %% [markdown]
# ### Step 9.

# %% [markdown]
# ### Step 10.

# %% [markdown]
# ### Step 11.

# %% [markdown]
# ### Step 12.

# %% [markdown]
# ### Step 13.

# %% [markdown]
# ### Step 14.

# %% [markdown]
# ### Step 15.

# %% [markdown]
# ### Step 16.

# %% [markdown]
# ### BONUS: Create your own question and answer it.
