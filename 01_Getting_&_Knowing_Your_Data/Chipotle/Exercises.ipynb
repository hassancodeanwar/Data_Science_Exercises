# %% [markdown]
# # Ex2 - Getting and Knowing your Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %%
pd.read_table('raw.githubusercontent.com_justmarkham_DAT8_master_data_chipotle.tsv.txt')
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_table('raw.githubusercontent.com_justmarkham_DAT8_master_data_chipotle.tsv.txt')

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
# Solution 1
len(chipo)
# Out:
# 4622

# %%
# Solution 2
chipo.shape[0]
# Out:
# 4622

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
len(chipo.columns)
# Out:
# 5

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
colimn_names = list(chipo.columns)
colimn_names
# Out:
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
item_name_list = chipo['item_name'].to_list
item_name_list
# Out:
# <bound method IndexOpsMixin.tolist of 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: category
# Categories (50, object): ['6 Pack Soft Drink', 'Barbacoa Bowl', 'Barbacoa Burrito', 'Barbacoa Crispy Tacos', ..., 'Veggie Crispy Tacos', 'Veggie Salad', 'Veggie Salad Bowl', 'Veggie Soft Tacos']>

# %% [markdown]
# ### Step 10. For the most-ordered item, how many items were ordered?

# %%
chipo.plot(x = 'item_name', y = 'quantity', kind='line')
plt.xlabel('item_name')
plt.ylabel('quantity')

plt.ylim(0, 16 )

plt.title('Plot of item_name and quantity')
plt.show()

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Assuming your DataFrame is named 'df' and contains columns 'column1' and 'column2'
# # Replace 'column1' and 'column2' with the actual column names from your DataFrame

# chipo.plot(x = 'item_name', y = 'quantity', kind='line')
# plt.xlabel('item_name')
# plt.ylabel('quantity')
# plt.title('Plot of item_name and quantity')

# # Find the maximum value and its corresponding index
# max_value = chipo['item_name'].max()
# max_index = chipo['quantity'].idxmax()

# # Highlight the highest peak
# plt.scatter(chipo['quantity'][max_index], max_value, color='red', zorder=5)
# plt.annotate(f'Max: {max_value}', xy=(chipo['quantity'][max_index], max_value),
#              xytext=(chipo['quantity'][max_index], max_value + 1),
#              arrowprops=dict(facecolor='black', arrowstyle='->'))

# plt.show()



import matplotlib.pyplot as plt

chipo.plot(x='item_name', y='quantity', kind='line')
plt.xlabel('item_name')
plt.ylabel('quantity')
plt.title('Plot of item_name and quantity')

# Find the maximum value and its corresponding index
max_value = chipo['quantity'].max()
max_index = chipo['quantity'].idxmax()

# Highlight the highest peak
plt.scatter(chipo['quantity'][max_index], max_value, color='red', zorder=5)
plt.annotate(f'Max: {max_value}', xy=(chipo['quantity'][max_index], max_value),
             xytext=(chipo['quantity'][max_index], max_value + 1),
             arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.show()

# %%
dataset = dict(chipo)
dataset
quantity_dict = {}

for order in dataset:
    item = order["item_name"]
    quantity = order["quantity"]

    if item in quantity_dict:
        quantity_dict[item] += quantity
    else:
        quantity_dict[item] = quantity

# print("Number of times each item was ordered based on quantity:")
# for item, quantity in quantity_dict.items():
#     print(item, ":", quantity)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 6
#       3 quantity_dict = {}
#       5 for order in dataset:
# ----> 6     item = order["item_name"]
#       7     quantity = order["quantity"]
#       9     if item in quantity_dict:
#
# TypeError: string indices must be integers

# %%
num_of_choice_description = list(chipo['choice_description'])
num_of_choice_description
# Out:
# [nan,
#  '[Clementine]',
#  '[Apple]',
#  nan,
#  '[Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]',
#  '[Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Guacamole, Lettuce]]',
#  nan,
#  '[Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Pinto Beans, Cheese, Sour Cream, Guacamole, Lettuce]]',
#  '[Tomatillo Green Chili Salsa, [Pinto Beans, Cheese, Sour Cream, Lettuce]]',
#  '[Fresh Tomato Salsa, [Rice, Black Beans, Pinto Beans, Cheese, Sour Cream, Lettuce]]',
#  nan,
#  '[Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream]]',
#  '[Roasted Chili Corn Salsa, [Rice, Black Beans, Cheese, Sour Cream]]',
#  '[Fresh Tomato Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Guacamole]]',
#  nan,
#  nan,
#  '[Tomatillo-Green Chili Salsa (Medium), [Pinto Beans, Cheese, Sour Cream]]',
#  '[Fresh Tomato Salsa (Mild), [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]',
#  '[Sprite]',
# ...

# %%
# Out:
# Most repeated element: nan
# Frequency of the most repeated element: 1246
# Second most repeated element: [Diet Coke]
# Frequency of the second most repeated element: 134

# %% [markdown]
# ### Step 11. What was the most ordered item in the choice_description column?

# %%
unique_elements = set(num_of_choice_description)
frequency_dict = {}
most_repeated_element = None
highest_frequency = 0
second_most_repeated_element = None
second_highest_frequency = 0

for element in unique_elements:
    frequency = num_of_choice_description.count(element)
    frequency_dict[element] = frequency

    if frequency > highest_frequency:
        second_most_repeated_element = most_repeated_element
        second_highest_frequency = highest_frequency
        most_repeated_element = element
        highest_frequency = frequency
    elif frequency > second_highest_frequency and element != most_repeated_element:
        second_most_repeated_element = element
        second_highest_frequency = frequency

# print("Frequency of each element:")
# for element, frequency in frequency_dict.items():
#     print(element, ":", frequency)

# print("Most repeated element:", most_repeated_element)
# print("Frequency of the most repeated element:", highest_frequency)

print("the most ordered item in the choice_description column:", second_most_repeated_element)
print("Frequency of most repeated element:", second_highest_frequency)
# Out:
# the most ordered item in the choice_description column: [Diet Coke]
# Frequency of most repeated element: 134

# %% [markdown]
# ### Step 12. How many items were orderd in total?

# %%
chipo.choice_description.sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0                                                     NaN
# 1                                            [Clementine]
# 2                                                 [Apple]
# 3                                                     NaN
# 4       [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
#                               ...
# 4617    [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# 4618    [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4619    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# 4620    [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...
# 4621    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# Name: choice_description, Length: 4622, dtype: object>

# %% [markdown]
# ### Step 13. Turn the item price into a float

# %%
chickisthereNULLS = set(chipo['item_price'].isna())
chickisthereNULLS
# Out:
# {False}

# %%
type(chipo['item_price'])
# Out:
# pandas.core.series.Series

# %%
def convert_to_float(string_value):
    cleaned_string = string_value.replace('$', '')
    return float(cleaned_string)

# Apply the conversion function to the Series
chipo['item_price'] = chipo['item_price'].apply(convert_to_float)

# Print the float Series
print(chipo['item_price'])
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %% [markdown]
# #### Step 13.a. Check the item price type

# %%
chipo['item_price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# #### Step 13.b. Create a lambda function and change the type of item price

# %%
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x))

# %% [markdown]
# #### Step 13.c. Check the item price type

# %%
chipo['item_price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %%
chipo['revenue'] = chipo['item_price'] * chipo['quantity'] 
chipo['revenue'].sum()
# Out:
# 39237.02

# %% [markdown]
# ### Step 15. How many orders were made in the period?

# %%
len(set(chipo['order_id']))
# Out:
# 1834

# %% [markdown]
# ### Step 16. What is the average revenue amount per order?

# %%
# Solution 1
###"Average revenue" refers to the total amount of money earned divided by the number of orders.

avg_revenue = chipo['revenue'].sum() / len(set(chipo['order_id']))
avg_revenue
# Out:
# 21.39423118865867

# %%
# Solution 2
average_revenue_per_order = chipo.groupby('order_id')['revenue'].mean()

average_revenue_per_order
# Out:
# order_id
# 1        2.890000
# 2       33.960000
# 3        6.335000
# 4       10.500000
# 5        6.850000
#           ...
# 1830    11.500000
# 1831     4.300000
# 1832     6.600000
# 1833    11.750000
# 1834     9.583333
# Name: revenue, Length: 1834, dtype: float64

# %% [markdown]
# ### Step 17. How many different items are sold?

# %%
num_different_items_sold = chipo['item_name'].nunique()
num_different_items_sold
# Out:
# 50
