# %% [markdown]
# # Iris

# %% [markdown]
# ### Introduction:
#
# This exercise may seem a little bit strange, but keep doing it.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import pandas_profiling
import numpy as np
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7828\2380940734.py:2: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data).

# %% [markdown]
# ### Step 3. Assign it to a variable called iris

# %%
iris = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data')
iris
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %% [markdown]
# ### Step 4. Create columns for the dataset

# %%
iris.columns = ['sepal_length', 'sepal_width', 'patel_length', 'patel_width', 'class']
iris
# Out:
#      sepal_length  sepal_width  patel_length  patel_width           class
# 0             4.9          3.0           1.4          0.2     Iris-setosa
# 1             4.7          3.2           1.3          0.2     Iris-setosa
# 2             4.6          3.1           1.5          0.2     Iris-setosa
# 3             5.0          3.6           1.4          0.2     Iris-setosa
# 4             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 144           6.7          3.0           5.2          2.3  Iris-virginica
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
# 1. sepal_length (in cm)
# 2. sepal_width (in cm)
# 3. petal_length (in cm)
# 4. petal_width (in cm)
# 5. class

# %% [markdown]
# ### Step 5.  Is there any missing value in the dataframe?

# %%
iris.isnull().sum()
# Out:
# 5.1            0
# 3.5            0
# 1.4            0
# 0.2            0
# Iris-setosa    0
# dtype: int64

# %% [markdown]
# ### Step 6.  Lets set the values of the rows 10 to 29 of the column 'petal_length' to NaN

# %%
# Assuming you have already imported pandas as pd and have a DataFrame named 'df'

# Set the values of rows 10 to 29 of the 'petal_length' column to NaN
iris.loc[10:29, 'petal_length'] = 'NaN'

# %% [markdown]
# ### Step 7. Good, now lets substitute the NaN values to 1.0

# %%
iris['petal_length'].fillna(1.0)
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 144    1.0
# 145    1.0
# 146    1.0
# 147    1.0
# 148    1.0
# Name: petal_length, Length: 149, dtype: object

# %% [markdown]
# ### Step 8. Now let's delete the column class

# %%
iris.drop('class', axis = 1 , inplace = True)

# %% [markdown]
# ### Step 9.  Set the first 3 rows as NaN

# %%
iris.iloc[:2] = 'Nan'

# %% [markdown]
# ### Step 10.  Delete the rows that have NaN

# %%
iris.dropna(inplace=True)
iris
# Out:
#    sepal_length sepal_width patel_length patel_width petal_length
# 0           Nan         Nan          Nan         Nan          Nan
# 1           Nan         Nan          Nan         Nan          Nan
# 10          4.8         3.4          1.6         0.2          NaN
# 11          4.8         3.0          1.4         0.1          NaN
# 12          4.3         3.0          1.1         0.1          NaN
# 13          5.8         4.0          1.2         0.2          NaN
# 14          5.7         4.4          1.5         0.4          NaN
# 15          5.4         3.9          1.3         0.4          NaN
# 16          5.1         3.5          1.4         0.3          NaN
# 17          5.7         3.8          1.7         0.3          NaN
# 18          5.1         3.8          1.5         0.3          NaN
# 19          5.4         3.4          1.7         0.2          NaN
# 20          5.1         3.7          1.5         0.4          NaN
# ...

# %% [markdown]
# ### Step 11. Reset the index so it begins with 0 again

# %%
iris.reset_index(drop=T, rueinplace=True)
iris
# Out:
#    sepal_length sepal_width patel_length patel_width petal_length
# 0           Nan         Nan          Nan         Nan          Nan
# 1           Nan         Nan          Nan         Nan          Nan
# 2           4.8         3.4          1.6         0.2          NaN
# 3           4.8         3.0          1.4         0.1          NaN
# 4           4.3         3.0          1.1         0.1          NaN
# 5           5.8         4.0          1.2         0.2          NaN
# 6           5.7         4.4          1.5         0.4          NaN
# 7           5.4         3.9          1.3         0.4          NaN
# 8           5.1         3.5          1.4         0.3          NaN
# 9           5.7         3.8          1.7         0.3          NaN
# 10          5.1         3.8          1.5         0.3          NaN
# 11          5.4         3.4          1.7         0.2          NaN
# 12          5.1         3.7          1.5         0.4          NaN
# ...

# %% [markdown]
# ### BONUS: Create your own question and answer it.
